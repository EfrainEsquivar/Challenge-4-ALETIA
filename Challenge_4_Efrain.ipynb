# %% [markdown]
# <a href="https://colab.research.google.com/github/EfrainEsquivar/Challenge-4-ALETIA/blob/main/Challenge_4_Efrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

Seasons = pd.read_csv("Seasons_Stats.csv")

# %%
Seasons.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
#Data frame shape (Number of rows and columns)
Seasons.shape
# Out:
# (24691, 53)

# %%
pd.options.display.max_columns = 50
Seasons.describe()
# Out:
#          Unnamed: 0          Year           Age             G            GS  \
# count  24691.000000  24624.000000  24616.000000  24624.000000  18233.000000
# mean   12345.000000   1992.594989     26.664405     50.837110     23.593375
# std     7127.822084     17.429594      3.841892     26.496161     28.632387
# min        0.000000   1950.000000     18.000000      1.000000      0.000000
# 25%     6172.500000   1981.000000     24.000000     27.000000      0.000000
# 50%    12345.000000   1996.000000     26.000000     58.000000      8.000000
# 75%    18517.500000   2007.000000     29.000000     75.000000     45.000000
# max    24690.000000   2017.000000     44.000000     88.000000     83.000000
#
#                  MP           PER           TS%          3PAr           FTr  \
# count  24138.000000  24101.000000  24538.000000  18839.000000  24525.000000
# mean    1209.720317     12.479071      0.493001      0.158604      0.325455
# ...

# %%
#We display cell numbers with Nan value
Seasons.isnull().sum()
# Out:
# Unnamed: 0        0
# Year             67
# Player           67
# Pos              67
# Age              75
# Tm               67
# G                67
# GS             6458
# MP              553
# PER             590
# TS%             153
# 3PAr           5852
# FTr             166
# ORB%           3899
# DRB%           3899
# TRB%           3120
# AST%           2136
# STL%           3899
# BLK%           3899
# TOV%           5109
# USG%           5051
# blanl         24691
# OWS             106
# DWS             106
# WS              106
# WS/48           590
# blank2        24691
# OBPM           3894
# DBPM           3894
# BPM            3894
# VORP           3894
# FG               67
# FGA              67
# FG%             166
# 3P             5764
# 3PA            5764
# 3P%            9275
# 2P               67
# 2PA              67
# 2P%             195
# eFG%            166
# FT               67
# FTA              67
# FT%             925
# ORB            3894
# ...

# %% [markdown]
# Columns blanl and blank2 has 24691 with NAN values. No data was ever entered into these columns. Let's remove them

# %%
Seasons = Seasons.drop(['blanl', 'blank2'], axis=1)
Seasons.isnull().sum()
# Out:
# Unnamed: 0       0
# Year            67
# Player          67
# Pos             67
# Age             75
# Tm              67
# G               67
# GS            6458
# MP             553
# PER            590
# TS%            153
# 3PAr          5852
# FTr            166
# ORB%          3899
# DRB%          3899
# TRB%          3120
# AST%          2136
# STL%          3899
# BLK%          3899
# TOV%          5109
# USG%          5051
# OWS            106
# DWS            106
# WS             106
# WS/48          590
# OBPM          3894
# DBPM          3894
# BPM           3894
# VORP          3894
# FG              67
# FGA             67
# FG%            166
# 3P            5764
# 3PA           5764
# 3P%           9275
# 2P              67
# 2PA             67
# 2P%            195
# eFG%           166
# FT              67
# FTA             67
# FT%            925
# ORB           3894
# DRB           3894
# TRB            379
# AST             67
# STL           3894
# ...

# %% [markdown]
# 67 rows do not have the name of players, those do not interest me. They are removed from the DF.

# %%
Seasons = Seasons.dropna(subset=["Player"])
Seasons = Seasons.dropna(subset=["Age"])
Seasons.isnull().sum()
# Out:
# Unnamed: 0       0
# Year             0
# Player           0
# Pos              0
# Age              0
# Tm               0
# G                0
# GS            6383
# MP             486
# PER            523
# TS%             86
# 3PAr          5777
# FTr             99
# ORB%          3824
# DRB%          3824
# TRB%          3045
# AST%          2061
# STL%          3824
# BLK%          3824
# TOV%          5034
# USG%          4976
# OWS             39
# DWS             39
# WS              39
# WS/48          523
# OBPM          3819
# DBPM          3819
# BPM           3819
# VORP          3819
# FG               0
# FGA              0
# FG%             99
# 3P            5689
# 3PA           5689
# 3P%           9200
# 2P               0
# 2PA              0
# 2P%            128
# eFG%            99
# FT               0
# FTA              0
# FT%            858
# ORB           3819
# DRB           3819
# TRB            312
# AST              0
# STL           3819
# ...

# %%
pd.options.display.max_columns = 50
Seasons.describe()
# Out:
#          Unnamed: 0          Year           Age             G            GS  \
# count  24616.000000  24616.000000  24616.000000  24616.000000  18233.000000
# mean   12357.779615   1992.607085     26.664405     50.847579     23.593375
# std     7123.714875     17.419490      3.841892     26.492239     28.632387
# min        0.000000   1950.000000     18.000000      1.000000      0.000000
# 25%     6192.750000   1981.000000     24.000000     27.000000      0.000000
# 50%    12361.500000   1996.000000     26.000000     58.000000      8.000000
# 75%    18526.250000   2007.000000     29.000000     75.000000     45.000000
# max    24690.000000   2017.000000     44.000000     88.000000     83.000000
#
#                  MP           PER           TS%          3PAr           FTr  \
# count  24130.000000  24093.000000  24530.000000  18839.000000  24517.000000
# mean    1210.051844     12.479243      0.493017      0.158604      0.325438
# ...

# %% [markdown]
# All the columns are filled with numerical values. No categorical variable in the columns

# %% [markdown]
# Now, we impute with the average value in the data with Nan for each of the columns

# %%
#TRB (Total Rebounds [available since the 1950-51 season]) is a parameter that does not interest me for my data analysis. 
#Proceed to delete it.
#Seasons = Seasons.dropna(subset=["TRB"])
#Seasons.isnull().sum()
Seasons['TRB'].fillna(Seasons['TRB'].mean(), inplace=True)
Seasons['FG%'].fillna(Seasons['FG%'].mean(), inplace=True)
Seasons['GS'].fillna(Seasons['GS'].mean(), inplace=True)
Seasons['MP'].fillna(Seasons['MP'].mean(), inplace=True)
Seasons['PER'].fillna(Seasons['PER'].mean(), inplace=True)
Seasons['TS%'].fillna(Seasons['TS%'].mean(), inplace=True)
Seasons['3PAr'].fillna(Seasons['3PAr'].mean(), inplace=True)
Seasons['FTr'].fillna(Seasons['FTr'].mean(), inplace=True)
Seasons['ORB%'].fillna(Seasons['ORB%'].mean(), inplace=True)
Seasons['DRB%'].fillna(Seasons['DRB%'].mean(), inplace=True)
Seasons['TRB%'].fillna(Seasons['TRB%'].mean(), inplace=True)
Seasons['AST%'].fillna(Seasons['AST%'].mean(), inplace=True)
Seasons['STL%'].fillna(Seasons['STL%'].mean(), inplace=True)
Seasons['BLK%'].fillna(Seasons['BLK%'].mean(), inplace=True)
Seasons['TOV%'].fillna(Seasons['TOV%'].mean(), inplace=True)
Seasons['USG%'].fillna(Seasons['USG%'].mean(), inplace=True)
Seasons['OWS'].fillna(Seasons['OWS'].mean(), inplace=True)
Seasons['DWS'].fillna(Seasons['DWS'].mean(), inplace=True)
Seasons['WS'].fillna(Seasons['WS'].mean(), inplace=True)
Seasons['WS/48'].fillna(Seasons['WS/48'].mean(), inplace=True)
Seasons['OBPM'].fillna(Seasons['OBPM'].mean(), inplace=True)
Seasons['DBPM'].fillna(Seasons['DBPM'].mean(), inplace=True)
Seasons['DRB%'].fillna(Seasons['DRB%'].mean(), inplace=True)
Seasons['BPM'].fillna(Seasons['BPM'].mean(), inplace=True)
Seasons['AST%'].fillna(Seasons['AST%'].mean(), inplace=True)
Seasons['VORP'].fillna(Seasons['VORP'].mean(), inplace=True)
Seasons['FG%'].fillna(Seasons['FG%'].mean(), inplace=True)
Seasons['3P'].fillna(Seasons['3P'].mean(), inplace=True)
Seasons['3PA'].fillna(Seasons['3PA'].mean(), inplace=True)
Seasons['3P%'].fillna(Seasons['3P%'].mean(), inplace=True)
Seasons['2P'].fillna(Seasons['2P'].mean(), inplace=True)
Seasons['2PA'].fillna(Seasons['2PA'].mean(), inplace=True)
Seasons['2P%'].fillna(Seasons['2P%'].mean(), inplace=True)
Seasons['eFG%'].fillna(Seasons['eFG%'].mean(), inplace=True)
Seasons['FT'].fillna(Seasons['FT'].mean(), inplace=True)
Seasons['FTA'].fillna(Seasons['FTA'].mean(), inplace=True)
Seasons['FT%'].fillna(Seasons['FT%'].mean(), inplace=True)
Seasons['ORB'].fillna(Seasons['ORB'].mean(), inplace=True)
Seasons['DRB'].fillna(Seasons['DRB'].mean(), inplace=True)
Seasons['TRB'].fillna(Seasons['TRB'].mean(), inplace=True)
Seasons['AST'].fillna(Seasons['AST'].mean(), inplace=True)
Seasons['STL'].fillna(Seasons['STL'].mean(), inplace=True)
Seasons['BLK'].fillna(Seasons['BLK'].mean(), inplace=True)
Seasons['TOV'].fillna(Seasons['TOV'].mean(), inplace=True)
Seasons.isnull().sum()
# Out:
# Unnamed: 0    0
# Year          0
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# PER           0
# TS%           0
# 3PAr          0
# FTr           0
# ORB%          0
# DRB%          0
# TRB%          0
# AST%          0
# STL%          0
# BLK%          0
# TOV%          0
# USG%          0
# OWS           0
# DWS           0
# WS            0
# WS/48         0
# OBPM          0
# DBPM          0
# BPM           0
# VORP          0
# FG            0
# FGA           0
# FG%           0
# 3P            0
# 3PA           0
# 3P%           0
# 2P            0
# 2PA           0
# 2P%           0
# eFG%          0
# FT            0
# FTA           0
# FT%           0
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# dtype: int64

# %% [markdown]
# 0 columns with Nan values!

# %%
Seasons.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G         GS  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0  23.593375
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0  23.593375
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0  23.593375
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0  23.593375
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0  23.593375
#
#             MP        PER    TS%      3PAr    FTr      ORB%       DRB%  \
# 0  1210.051844  12.479243  0.368  0.158604  0.467  6.181565  13.708657
# 1  1210.051844  12.479243  0.435  0.158604  0.387  6.181565  13.708657
# 2  1210.051844  12.479243  0.394  0.158604  0.259  6.181565  13.708657
# 3  1210.051844  12.479243  0.312  0.158604  0.395  6.181565  13.708657
# 4  1210.051844  12.479243  0.308  0.158604  0.378  6.181565  13.708657
#
#       TRB%       AST%      STL%      BLK%       TOV%       USG%  OWS  DWS  \
# ...

# %%
Seasons.describe()
# Out:
#          Unnamed: 0          Year           Age             G            GS  \
# count  24616.000000  24616.000000  24616.000000  24616.000000  24616.000000
# mean   12357.779615   1992.607085     26.664405     50.847579     23.593375
# std     7123.714875     17.419490      3.841892     26.492239     24.641934
# min        0.000000   1950.000000     18.000000      1.000000      0.000000
# 25%     6192.750000   1981.000000     24.000000     27.000000      1.000000
# 50%    12361.500000   1996.000000     26.000000     58.000000     23.593375
# 75%    18526.250000   2007.000000     29.000000     75.000000     27.000000
# max    24690.000000   2017.000000     44.000000     88.000000     83.000000
#
#                  MP           PER           TS%          3PAr           FTr  \
# count  24616.000000  24616.000000  24616.000000  24616.000000  24616.000000
# mean    1210.051844     12.479243      0.493017      0.158604      0.325438
# ...

# %% [markdown]
# Normalization

# %%
Seasons["Year"] =  (Seasons["Year"] - Seasons["Year"].min()) / (Seasons["Year"].max() - Seasons["Year"].min())
Seasons["Age"] =  (Seasons["Age"] - Seasons["Age"].min()) / (Seasons["Age"].max() - Seasons["Age"].min())
Seasons["G"] =  (Seasons["G"] - Seasons["G"].min()) / (Seasons["G"].max() - Seasons["G"].min())
Seasons["GS"] =  (Seasons["GS"] - Seasons["GS"].min()) / (Seasons["GS"].max() - Seasons["GS"].min())
Seasons["MP"] =  (Seasons["MP"] - Seasons["MP"].min()) / (Seasons["MP"].max() - Seasons["MP"].min())
Seasons["PER"] =  (Seasons["PER"] - Seasons["PER"].min()) / (Seasons["PER"].max() - Seasons["PER"].min())
Seasons["TS%"] =  (Seasons["TS%"] - Seasons["TS%"].min()) / (Seasons["TS%"].max() - Seasons["TS%"].min())
Seasons["3PAr"] =  (Seasons["3PAr"] - Seasons["3PAr"].min()) / (Seasons["3PAr"].max() - Seasons["3PAr"].min())
Seasons["FTr"] =  (Seasons["FTr"] - Seasons["FTr"].min()) / (Seasons["FTr"].max() - Seasons["FTr"].min())
Seasons["ORB%"] =  (Seasons["ORB%"] - Seasons["ORB%"].min()) / (Seasons["ORB%"].max() - Seasons["ORB%"].min())
Seasons["DRB%"] =  (Seasons["DRB%"] - Seasons["DRB%"].min()) / (Seasons["DRB%"].max() - Seasons["DRB%"].min())
Seasons["TRB%"] =  (Seasons["TRB%"] - Seasons["TRB%"].min()) / (Seasons["TRB%"].max() - Seasons["TRB%"].min())
Seasons["AST%"] =  (Seasons["AST%"] - Seasons["AST%"].min()) / (Seasons["AST%"].max() - Seasons["AST%"].min())
Seasons["STL%"] =  (Seasons["STL%"] - Seasons["STL%"].min()) / (Seasons["STL%"].max() - Seasons["STL%"].min())
Seasons["BLK%"] =  (Seasons["BLK%"] - Seasons["BLK%"].min()) / (Seasons["BLK%"].max() - Seasons["BLK%"].min())
Seasons["TOV%"] =  (Seasons["TOV%"] - Seasons["TOV%"].min()) / (Seasons["TOV%"].max() - Seasons["TOV%"].min())
Seasons["USG%"] =  (Seasons["USG%"] - Seasons["USG%"].min()) / (Seasons["USG%"].max() - Seasons["USG%"].min())
Seasons["OWS"] =  (Seasons["OWS"] - Seasons["OWS"].min()) / (Seasons["OWS"].max() - Seasons["OWS"].min())
Seasons["DWS"] =  (Seasons["DWS"] - Seasons["DWS"].min()) / (Seasons["DWS"].max() - Seasons["DWS"].min())
Seasons["WS"] =  (Seasons["WS"] - Seasons["WS"].min()) / (Seasons["WS"].max() - Seasons["WS"].min())
Seasons["WS/48"] =  (Seasons["WS/48"] - Seasons["WS/48"].min()) / (Seasons["WS/48"].max() - Seasons["WS/48"].min())
Seasons["OBPM"] =  (Seasons["OBPM"] - Seasons["OBPM"].min()) / (Seasons["OBPM"].max() - Seasons["OBPM"].min())
Seasons["DBPM"] =  (Seasons["DBPM"] - Seasons["DBPM"].min()) / (Seasons["DBPM"].max() - Seasons["DBPM"].min())
Seasons["BPM"] =  (Seasons["BPM"] - Seasons["BPM"].min()) / (Seasons["BPM"].max() - Seasons["BPM"].min())
Seasons["VORP"] =  (Seasons["VORP"] - Seasons["VORP"].min()) / (Seasons["VORP"].max() - Seasons["VORP"].min())
Seasons["FG"] =  (Seasons["FG"] - Seasons["FG"].min()) / (Seasons["FG"].max() - Seasons["FG"].min())
Seasons["FGA"] =  (Seasons["FGA"] - Seasons["FGA"].min()) / (Seasons["FGA"].max() - Seasons["FGA"].min())
Seasons["FG%"] =  (Seasons["FG%"] - Seasons["FG%"].min()) / (Seasons["FG%"].max() - Seasons["FG%"].min())
Seasons["3P"] =  (Seasons["3P"] - Seasons["3P"].min()) / (Seasons["3P"].max() - Seasons["3P"].min())
Seasons["3PA"] =  (Seasons["3PA"] - Seasons["3PA"].min()) / (Seasons["3PA"].max() - Seasons["3PA"].min())
Seasons["3P%"] =  (Seasons["3P%"] - Seasons["3P%"].min()) / (Seasons["3P%"].max() - Seasons["3P%"].min())
Seasons["2P"] =  (Seasons["2P"] - Seasons["2P"].min()) / (Seasons["2P"].max() - Seasons["2P"].min())
Seasons["2PA"] =  (Seasons["2PA"] - Seasons["2PA"].min()) / (Seasons["2PA"].max() - Seasons["2PA"].min())
Seasons["2P%"] =  (Seasons["2P%"] - Seasons["2P%"].min()) / (Seasons["2P%"].max() - Seasons["2P%"].min())
Seasons["eFG%"] =  (Seasons["eFG%"] - Seasons["eFG%"].min()) / (Seasons["eFG%"].max() - Seasons["eFG%"].min())
Seasons["FT"] =  (Seasons["FT"] - Seasons["FT"].min()) / (Seasons["FT"].max() - Seasons["FT"].min())
Seasons["FTA"] =  (Seasons["FTA"] - Seasons["FTA"].min()) / (Seasons["FTA"].max() - Seasons["FTA"].min())
Seasons["FT%"] =  (Seasons["FT%"] - Seasons["FT%"].min()) / (Seasons["FT%"].max() - Seasons["FT%"].min())
Seasons["ORB"] =  (Seasons["ORB"] - Seasons["ORB"].min()) / (Seasons["ORB"].max() - Seasons["ORB"].min())
Seasons["DRB"] =  (Seasons["DRB"] - Seasons["DRB"].min()) / (Seasons["DRB"].max() - Seasons["DRB"].min())
Seasons["TRB"] =  (Seasons["TRB"] - Seasons["TRB"].min()) / (Seasons["TRB"].max() - Seasons["TRB"].min())
Seasons["AST"] =  (Seasons["AST"] - Seasons["AST"].min()) / (Seasons["AST"].max() - Seasons["AST"].min())
Seasons["STL"] =  (Seasons["STL"] - Seasons["STL"].min()) / (Seasons["STL"].max() - Seasons["STL"].min())
Seasons["BLK"] =  (Seasons["BLK"] - Seasons["BLK"].min()) / (Seasons["BLK"].max() - Seasons["BLK"].min())
Seasons["TOV"] =  (Seasons["TOV"] - Seasons["TOV"].min()) / (Seasons["TOV"].max() - Seasons["TOV"].min())
Seasons["PF"] =  (Seasons["PF"] - Seasons["PF"].min()) / (Seasons["PF"].max() - Seasons["PF"].min())
Seasons["PTS"] =  (Seasons["PTS"] - Seasons["PTS"].min()) / (Seasons["PTS"].max() - Seasons["PTS"].min())
#Seasons["MP"] =  (Seasons["MP"] - Seasons["MP"].mean()) / Seasons["MP"].std()

Seasons.describe()
# Out:
#          Unnamed: 0          Year           Age             G            GS  \
# count  24616.000000  24616.000000  24616.000000  24616.000000  24616.000000
# mean   12357.779615      0.635927      0.333246      0.572961      0.284258
# std     7123.714875      0.259992      0.147765      0.304508      0.296891
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     6192.750000      0.462687      0.230769      0.298851      0.012048
# 50%    12361.500000      0.686567      0.307692      0.655172      0.284258
# 75%    18526.250000      0.850746      0.423077      0.850575      0.325301
# max    24690.000000      1.000000      1.000000      1.000000      1.000000
#
#                  MP           PER           TS%          3PAr           FTr  \
# count  24616.000000  24616.000000  24616.000000  24616.000000  24616.000000
# mean       0.311708      0.469182      0.433994      0.158604      0.054240
# ...

# %%
Seasons.head(500)
# Out:
#      Unnamed: 0      Year           Player  Pos       Age   Tm         G  \
# 0             0  0.000000  Curly Armstrong  G-F  0.500000  FTW  0.712644
# 1             1  0.000000     Cliff Barker   SG  0.423077  INO  0.551724
# 2             2  0.000000    Leo Barnhorst   SF  0.269231  CHS  0.758621
# 3             3  0.000000       Ed Bartels    F  0.230769  TOT  0.160920
# 4             4  0.000000       Ed Bartels    F  0.230769  DNN  0.137931
# ..          ...       ...              ...  ...       ...  ...       ...
# 497         497  0.029851      Bob Brannum   PF  0.307692  BOS  0.747126
# 498         498  0.029851    Frankie Brian   SG  0.384615  FTW  0.747126
# 499         499  0.029851       Stan Brown    F  0.153846  PHW  0.160920
# 500         500  0.029851       Walt Budko   PF  0.307692  PHW  0.712644
# 501         501  0.029851       Art Burris   SF  0.346154  TOT  0.459770
#
#            GS        MP       PER       TS%      3PAr       FTr      ORB%  \
# ...

# %%
Seasons ['FG%'].hist()

# %%
Seasons ['WS'].hist()

# %%
Seasons ['TS%'].hist()

# %% [markdown]
# Label encoding

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
Seasons ['Pos'] = labelencoder.fit_transform(Seasons ['Pos'])
Seasons ['Tm'] = labelencoder.fit_transform(Seasons ['Tm'])
Seasons ['Player'] = labelencoder.fit_transform(Seasons ['Player'])
Seasons.head(500)
# Out:
#      Unnamed: 0      Year  Player  Pos       Age  Tm         G        GS  \
# 0             0  0.000000     789    8  0.500000  21  0.712644  0.284258
# 1             1  0.000000     719   19  0.423077  25  0.551724  0.284258
# 2             2  0.000000    2414   15  0.269231  13  0.758621  0.284258
# 3             3  0.000000    1192    4  0.230769  61  0.160920  0.284258
# 4             4  0.000000    1192    4  0.230769  20  0.137931  0.284258
# ..          ...       ...     ...  ...       ...  ..       ...       ...
# 497         497  0.029851     349    9  0.307692   4  0.747126  0.284258
# 498         498  0.029851    1343   19  0.384615  21  0.747126  0.284258
# 499         499  0.029851    3447    4  0.153846  47  0.160920  0.284258
# 500         500  0.029851    3793    9  0.307692  47  0.712644  0.284258
# 501         501  0.029851     208   15  0.346154  61  0.459770  0.284258
#
#            MP       PER       TS%      3PAr       FTr      ORB%      DRB%  \
# ...

# %% [markdown]
# PCA

# %%
from sklearn.decomposition import PCA

X = Seasons.iloc[:,6:51]
d = 2

pca = PCA(n_components= d)
X_d = pca.fit_transform(X)

# %%
X.shape
# Out:
# (24616, 45)

# %%
X_d.shape
# Out:
# (24616, 2)

# %% [markdown]
# Principal Components

# %%
C1 = pca.components_.T[:,:]
C1
# Out:
# array([[ 4.27928170e-01, -1.21637795e-01],
#        [ 3.85730747e-01,  1.90506527e-01],
#        [ 3.78487589e-01,  4.82675302e-02],
#        [ 2.43104852e-02,  9.71625838e-06],
#        [ 5.19644280e-02, -1.97705637e-03],
#        [-1.48931817e-02,  5.63138269e-01],
#        [ 5.90717754e-04, -4.02172428e-02],
#        [-1.42883006e-03, -1.08800838e-01],
#        [ 1.03120595e-02, -1.23911403e-01],
#        [ 4.47377001e-03, -1.17523309e-01],
#        [ 3.12699896e-02,  1.73327400e-01],
#        [ 3.09948654e-03,  2.59886761e-02],
#        [ 1.11670347e-03, -3.51694814e-02],
#        [-1.56664914e-02, -3.38558308e-02],
#        [ 1.80841595e-02,  3.75324352e-02],
#        [ 1.08130797e-01,  5.21759560e-02],
#        [ 9.75238136e-02, -3.97476064e-02],
#        [ 1.48437114e-01,  1.94371078e-02],
#        [ 1.62845885e-02, -2.94691703e-03],
#        [ 2.57843785e-02,  3.14308037e-02],
#        [ 1.29196931e-02, -3.48319242e-02],
#        [ 3.36300316e-02,  9.21792686e-03],
# ...

# %% [markdown]
# Choosing number of components

# %%
def get_pca_components(pca,var):
  cumm_var = pca.explained_variance_ratio_
  total_var = 0
  N_COMPONENTS = 0
  for i in cumm_var:
    N_COMPONENTS += 1
    total_var += i
    if total_var >= var:
      break
  return N_COMPONENTS

# %%
pca = PCA().fit(X)
n_components = get_pca_components(pca, 0.67)

# %%
n_components
# Out:
# 2

# %%
pca.explained_variance_ratio_
# Out:
# array([5.89133570e-01, 8.38143620e-02, 6.97390690e-02, 4.56983969e-02,
#        4.04217067e-02, 2.94976658e-02, 2.32968542e-02, 2.03775620e-02,
#        1.55838407e-02, 1.15752226e-02, 9.37478969e-03, 8.34470692e-03,
#        7.50383995e-03, 6.51830682e-03, 5.03599886e-03, 4.47509481e-03,
#        3.98191446e-03, 3.50175799e-03, 3.46239602e-03, 2.69625709e-03,
#        2.32996080e-03, 2.02823126e-03, 1.73607552e-03, 1.60297848e-03,
#        1.41571266e-03, 1.30944980e-03, 1.17279648e-03, 1.15536475e-03,
#        9.43338052e-04, 6.29499739e-04, 4.21656470e-04, 3.35238042e-04,
#        2.19878599e-04, 1.75503995e-04, 1.26730568e-04, 9.33247856e-05,
#        8.06639328e-05, 7.65403788e-05, 7.23873386e-05, 2.82111935e-05,
#        1.07747179e-05, 2.28076187e-06, 8.96981410e-08, 3.16153471e-33,
#        3.16153471e-33])

# %%
PC_values = np.arange(pca.n_components_) + 1
plt.plot(PC_values, pca.explained_variance_ratio_, 'o-', linewidth=2, color='blue' )
plt.title('Screen Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %%
pca = PCA(n_components = 0.67)
X_d = pca.fit_transform(X)

# %% [markdown]
# Loadings

# %%
dfPCA = pd.DataFrame(pca.components_, columns=list(X.columns))
dfPCA
# Out:
#           G        GS        MP      PER       TS%      3PAr       FTr  \
# 0  0.427928  0.385731  0.378488  0.02431  0.051964 -0.014893  0.000591
# 1 -0.121638  0.190507  0.048268  0.00001 -0.001977  0.563138 -0.040217
#
#        ORB%      DRB%      TRB%      AST%      STL%      BLK%      TOV%  \
# 0 -0.001429  0.010312  0.004474  0.031270  0.003099  0.001117 -0.015666
# 1 -0.108801 -0.123911 -0.117523  0.173327  0.025989 -0.035169 -0.033856
#
#        USG%       OWS       DWS        WS     WS/48      OBPM      DBPM  \
# 0  0.018084  0.108131  0.097524  0.148437  0.016285  0.025784  0.012920
# 1  0.037532  0.052176 -0.039748  0.019437 -0.002947  0.031431 -0.034832
#
#         BPM      VORP        FG       FGA       FG%        3P       3PA  \
# 0  0.033630  0.089333  0.176692  0.187873  0.054896  0.054587  0.069064
# 1  0.009218  0.049806  0.021782  0.051017 -0.117476  0.261894  0.316726
#
#         3P%        2P       2PA       2P%      eFG%        FT       FTA  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X)
X2=scaler.transform(X)

# %%
X2
# Out:
# array([[ 0.45872559,  0.        ,  0.        , ...,  0.        ,
#          1.18686969, -0.10601011],
#        [-0.0697418 ,  0.        ,  0.        , ...,  0.        ,
#         -0.20484111, -0.46914455],
#        [ 0.60971628,  0.        ,  0.        , ...,  0.        ,
#          0.89201571, -0.14658379],
#        ...,
#        [-1.20217192, -0.95746762, -1.18275962, ..., -1.17275348,
#         -1.17196218, -0.98848765],
#        [-0.25848015, -0.22699064, -0.39393256, ..., -0.56108191,
#         -0.45251846, -0.54826323],
#        [-0.48496618, -0.51106502, -0.64506934, ..., -0.72639855,
#         -0.59404837, -0.45900113]])

# %%
pca2 = PCA(n_components= 1 )
X_d2 = pca2.fit_transform(X2)

# %%
dfPCA2 = pd.DataFrame(pca2.components_, columns=list(X.columns))
dfPCA2
# Out:
#           G        GS       MP       PER       TS%      3PAr       FTr  \
# 0 -0.182793 -0.173881 -0.21793 -0.162804 -0.117396  0.012129 -0.013106
#
#        ORB%      DRB%      TRB%      AST%      STL%      BLK%      TOV%  \
# 0 -0.004608 -0.034327 -0.024851 -0.056333 -0.020535 -0.015615  0.045641
#
#        USG%       OWS       DWS        WS     WS/48      OBPM      DBPM  \
# 0 -0.063293 -0.188127 -0.191184 -0.210639 -0.139421 -0.156063 -0.075868
#
#        BPM      VORP        FG       FGA      FG%        3P       3PA  \
# 0 -0.16261 -0.176412 -0.217587 -0.213589 -0.10747 -0.091573 -0.095358
#
#         3P%        2P       2PA       2P%      eFG%        FT       FTA  \
# 0 -0.014228 -0.211677 -0.206882 -0.099167 -0.104002 -0.204701 -0.206035
#
#        FT%       ORB       DRB       TRB       AST       STL      BLK  \
# 0 -0.05932 -0.162964 -0.186803 -0.186293 -0.164903 -0.181017 -0.12784
#
#         TOV        PF       PTS
# 0 -0.192809 -0.192631 -0.219122

# %%
pca2.explained_variance_ratio_
# Out:
# array([0.41019825])

# %%
np.cumsum(pca2.explained_variance_ratio_)
# Out:
# array([0.41019825])

# %% [markdown]
# Explained variance

# %%
cumVar = pd.DataFrame(np.cumsum(pca.explained_variance_ratio_)*100, 
                      columns=["cumVarPerc"])
expVar = pd.DataFrame(pca.explained_variance_ratio_*100, columns=["VarPerc"])
pd.concat([expVar, cumVar], axis=1)\
    .rename(index={0: "PC1", 1: "PC2"})
# Out:
#        VarPerc  cumVarPerc
# PC1  58.913357   58.913357
# PC2   8.381436   67.294793

# %%
componentsDf = pd.DataFrame(data = X_d, columns = ['PC1', 'PC2'])
#pcaDf = pd.concat([componentsDf, Y], axis=1)

plt.figure(figsize=(22, 12))
sns.scatterplot(data=componentsDf, x="PC1", y="PC2")

# %%
def biplot(score,coeff,labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley,s=5)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'green', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
 
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))
    plt.grid()

# %%
plt.figure(figsize=(22, 12))
biplot(X_d, np.transpose(pca.components_), list(X.columns))
